# %%
import numpy as np
import math 
from tkinter import *


value = "0"
x = 0
y = 0
mod = 1
memory = "0"

def clear () :
    global value
    value = "0"
    before.set('')
    final.set('0')


def backspace () : 
    global value
    value = value[:-1]
    final.set(value) 

def get_value_num(new_str) :
    global value
    label_20.config(bg = "BlanchedAlmond")
    label_21.config(bg = "BlanchedAlmond")
    label_22.config(bg = "yellow")
    label_23.config(bg = "BlanchedAlmond")
    if (value == "0") or (value == "0.0") : 
        value = new_str
        final.set(value)
    else :
        value = value + new_str
        final.set(value)
        
def get_value_sign(new_str) :
    global value
    label_20.config(bg = "BlanchedAlmond")
    label_21.config(bg = "BlanchedAlmond")
    label_22.config(bg = "yellow")
    label_23.config(bg = "BlanchedAlmond")
    if (value == "0") or (value == "0.0") : 
        value = new_str
        final.set(value)
    else :
        value = value + new_str
        final.set(value)

def calculate () : 
    global value
    try : 
        before.set(value)
        ans = eval(value) 
        value = str(ans)
        final.set(value)

    except : 
        final.set(" error ")
        value = "0"

        
def convertsigned () :    # +/- method
    global value
    try :
        temp = eval(value) 
        temp = temp * (-1)
        value = str(temp)
        final.set(value)
    except :
        final.set(" error ")
        value = "0"

def transfer () :
    global mod 
    if (mod == 1) :
        label_40.config(text = "2nd", bg = "BlanchedAlmond", command = transfer)
        label_61.config(text = "asin", bg = 'BlanchedAlmond', command = arc_sin)
        label_71.config(text = "asinh", bg = 'BlanchedAlmond', command = arc_sinh)
        label_62.config(text = "acos", bg = 'BlanchedAlmond', command = arc_cos)
        label_72.config(text = "acosh", bg = 'BlanchedAlmond', command = arc_cosh)
        label_63.config(text = "atan", bg = 'BlanchedAlmond', command = arc_tan)
        label_73.config(text = "atanh", bg = 'BlanchedAlmond', command = arc_tanh)
        label_44.config(text = "yˣ", bg = 'BlanchedAlmond', command = pow_y_x)
        label_54.config(text = "logₓy", bg = 'BlanchedAlmond', command = log_x_y)
        label_45.config(text = "2ˣ", bg = 'BlanchedAlmond', command = pow_2)
        label_55.config(text = "log2", bg = 'BlanchedAlmond', command = log_2)
        mod = 2
    else :
        label_40.config(text = "1st", bg = "plum", command = transfer)
        label_61.config(text = "sin", bg = 'plum', command = sin)
        label_71.config(text = "sinh", bg = 'plum', command = sinh)
        label_62.config(text = "cos", bg = 'plum', command = cos)
        label_72.config(text = "cosh", bg = 'plum', command = cosh)
        label_63.config(text = "tan", bg = 'plum', command = tan)
        label_73.config(text = "tanh", bg = 'plum', command = tanh)
        label_44.config(text = "eˣ", bg = 'plum', command = natural_pow)
        label_54.config(text = "ln", bg = 'plum', command = natural_log)
        label_45.config(text = "10ˣ", bg = 'plum', command = pow_10)
        label_55.config(text = "log10", bg = 'plum', command = log_10)
        mod = 1


def Binary () :
    global value
    try :
        temp = eval(value)
        value = str(temp)
        final.set(bin(temp)[2:]) 
        label_20.config(bg = "yellow")
        label_21.config(bg = "BlanchedAlmond")
        label_22.config(bg = "BlanchedAlmond")
        label_23.config(bg = "BlanchedAlmond")
    except : 
        final.set(" error ")
        value = "0"   
        
def Octal () :
    global value
    try :
        temp = eval(value)
        value = str(temp)
        final.set(oct(temp)[2:]) 
        label_20.config(bg = "BlanchedAlmond")
        label_21.config(bg = "yellow")
        label_22.config(bg = "BlanchedAlmond")
        label_23.config(bg = "BlanchedAlmond")
    except :
        final.set(" error ")
        value = "0"  

def Decimal () :
    global value
    try :
        temp = eval(value)
        value = str(temp)
        final.set(value) 
        label_20.config(bg = "BlanchedAlmond")
        label_21.config(bg = "BlanchedAlmond")
        label_22.config(bg = "yellow")
        label_23.config(bg = "BlanchedAlmond")
    except : 
        final.set(" error ")
        value = "0"  

def Hexadecimal () :
    global value
    try :
        temp = eval(value)
        value = str(temp)
        final.set(hex(temp)[2:]) 
        label_20.config(bg = "BlanchedAlmond")
        label_21.config(bg = "BlanchedAlmond")
        label_22.config(bg = "BlanchedAlmond")
        label_23.config(bg = "yellow")
    except : 
        final.set(" error ")
        value = "0"   


def factorial () :    # factorial method
    global value
    try :
        temp = eval(value)
        value = str(temp)
        before.set(value + '!')
        if (value.isdigit()) :
            value = str(math.factorial(temp))
            final.set(str(value))
        else :
            final.set(" error ")
            value = "0"   
    except : 
        final.set(" error ")
        value = "0"
            

# rad & degree
    
def rad () :
    global value
    temp = math.degrees(eval(value))
    value = str(temp)
    label_50.configure(text = "degree", command = degree)

def degree () :
    global value
    temp = math.radians(eval(value))
    value = str(temp)
    label_50.configure(text = "rad", command = rad)

# Constants         

def e () :    # e
    value = str(math.e)
    final.set(value)

def pi () :    # pi
    value = str(math.pi)
    final.set(value)

def rand () :    # rand
    value = str(np.random.rand())
    final.set(value)


# Memory function

def mc () :
    global value, memory
    label_33.configure(bg = "grey")
    memory = "0"

def m_p () :        
    global value, memory
    try :
        temp = eval(value)
        value = str(temp)
        memory = str(eval(memory + "+" + value))
        final.set(value)
        label_33.configure(bg = "pink")
    except : 
        final.set(" error ")
        value = "0"

def m_s () :
    global value, memory
    try :
        temp = eval(value)
        value = str(temp)
        memory = str(eval(memory + "-" + value))
        final.set(value)
    except : 
        final.set(" error ")
        value = "0"

def mr () :
    value = str(memory)
    final.set(value)


# pow functions

def square () :    # square method
    global value
    try : 
        if (value == "0") or (value == "0.0") :
            final.set("0")
        else :
            temp = eval(value)
            before.set('(' + str(temp) + ')^2')
            value = str(math.pow(temp, 2))
            final.set(str(value))
    except : 
        final.set(" error ")
        value = "0"

def cube () :    # cube method
    global value
    try : 
        if (value == "0") or (value == "0.0") :
            final.set("0")
        else :
            temp = eval(value) 
            before.set('(' + str(temp) + ')^3')
            value = str(math.pow(temp, 3))
            final.set(value)
    except : 
        final.set(" error ")     
        value = "0"

def squareroot () :    # sqrt method
    global value
    try : 
        if (value == "0") or (value == "0.0") :
            final.set("0")
        else :
            temp = eval(value) 
            before.set('\u221A(' + str(temp) + ')')
            value = str(math.sqrt(temp))
            final.set(value)
    except :
        value.set(" error ")
        value = "0"

def cuberoot () :    # cuberoot method
    global value
    try :
        if (value == "0") or (value == "0.0") :
            final.set("0")
        else :
            temp = eval(value) 
            before.set('\u221B(' + str(temp) + ')')
            value = str(math.pow(temp, (1/3)))
            final.set(value)
    except : 
        final.set(" error ")
        value = "0"

def pow_2 () :    # pow_2 method
    global value
    try : 
        temp = eval(value) 
        before.set('2^(' + str(temp) + ')')
        value = str(math.pow(2, temp))
        final.set(value)
    except : 
        final.set(" error ")   
        value = "0"

def pow_10 () :    # pow_2 method
    global value
    try : 
        temp = eval(value)
        before.set('10^(' + str(temp) + ')')
        value = str(math.pow(10, temp))
        final.set(value)
    except : 
        final.set(" error ") 
        value = "0"

def pow_x_y () :
    global value, x, y
    try :
        if x == 0 :
            x = eval(value)
            value = "0"
        else :
            y = eval(value)
            before.set(str(x) + '^(' + str(y) + ')')
            value = str(math.pow(x, y))
            final.set(value)
            x = 0
            y = 0
    except :
        final.set(" error ")   
        value = "0"

def pow_y_x () :
    global value, x, y
    try :
        if x == 0 :
            x = eval(value)
            value = "0"
        else :
            y = eval(value)
            before.set(str(y) + '^(' + str(x) + ')')
            value = str(math.pow(y, x))
            final.set(value)
            x = 0
            y = 0
    except :
        final.set(" error ")   
        value = "0"

def x_root_of_y () :
    global value, x, y
    try :
        if x == 0 :
            x = eval(value)
            value = "0"
        else :
            y = eval(value)
            before.set(str(y) + '\u221A(' + str(x) + ')')
            value = str(math.pow(x, (1/y)))
            final.set(value)
            x = 0
            y = 0
    except :
        final.set(" error ")
        value = "0"    


# division functions       

def percent () :    # % method
    global value
    try :
        temp = eval(value)
        before.set(str(temp) + '%')
        value = str(temp*0.01)
        before.set('')
        final.set(value)
    except :
        final.set(" error ")
        value = "0"

def over_x () :    # 1/x method
    global value
    try : 
        temp = eval(value)
        before.set('1/' + str(temp))
        value = str(1/temp)
        final.set(value)
    except :
        final.set(" error ")  
        value = "0"

# log functions

def log_2 () :    # log2 method
    global value
    try :
        temp = eval(value)
        before.set('log(2, ' + str(temp) + ')')
        value = str(math.log2(temp))
        final.set(value)
    except :
        final.set(" error ")
        value = "0"

def log_10 () :    #log10 method
    global value
    try :
        temp = eval(value)
        before.set('log(10, ' + str(temp) + ')')
        vale = str(math.log10(temp))
        final.set(value)
    except :
        final.set(" error ")
        value = "0"

def log_x_y () :    # log_x_y method
    global value, x, y
    try :
        if x == 0 :
            x = eval(value)
            value = "0"
        else :
            y = eval(value)
            before.set('log(' + str(y) + ', ' + str(x) + ')')
            value = str(math.log(y, x))
            final.set(value)
            x = 0
            y = 0
    except :
        final.set(" error ")   
        value = "0"


# Natural functions        

def natural_log () :
    """ ln method """
    global value
    try :
        temp = eval(value)
        before.set('ln(' + str(temp) + ')')
        value = str(math.log(temp))
        final.set(value)
    except :
        final.set(" error ")
        value = "0"

def natural_pow () :
    """ e^x """
    global value
    try :
        temp = eval(value)
        before.set('e^(' + str(temp) + ')')
        value = str(math.exp(temp))
        final.set(value)
    except :
        final.set(" error ")
        value = "0"


# Trigonometric functions

def sin () :
    """ sin method """
    global value
    try :
        temp = eval(value)
        before.set('sin(' + str(temp) + ')')
        value = str(math.sin(temp))
        final.set(value)
    except :
        final.set(" error ")
        value = "0"

def cos () :
    """ cos method """
    global value
    try :
        temp = eval(value)
        before.set('cos(' + str(temp) + ')')
        value = str(math.cos(temp))
        final.set(value)
    except :
        final.set(" error ")
        value = "0"

def tan () :
    """ tan method """
    global value
    try :
        temp = eval(value)
        before.set('tan(' + str(temp) + ')')
        value = str(math.tan(temp))
        final.set(value)
    except :
        final.set(" error ")
        value = "0"

# Hyperbolic functions

def sinh () :
    """ sinh method """
    global value
    try :
        temp = eval(value)
        before.set('sinh(' + str(temp) + ')')
        value = str(math.sinh(temp))
        final.set(value)
    except :
        final.set(" error ")
        value = "0"

def cosh () :
    """ cosh method """
    global value
    try :
        temp = eval(value)
        before.set('cosh(' + str(temp) + ')')
        value = str(math.cosh(temp))
        final.set(value)
    except :
        final.set(" error ")
        value = "0"

def tanh () :
    """ tanh method """
    global value
    try :
        temp = eval(value)
        before.set('tanh(' + str(temp) + ')')
        value = str(math.tanh(temp))
        final.set(value)
    except :
        final.set(" error ")
        value = "0"

# Trigonometric functions (arc)      

def arc_sin () :
    """ arcsin method """
    global value
    try :
        temp = eval(value)
        before.set('asin(' + str(temp) + ')')
        value = str(math.asin(temp))
        final.set(value)
    except :
        final.set(" error ")
        value = "0"

def arc_cos () :
    """ arccos method """
    global value
    try :
        temp = eval(value)
        before.set('acos(' + str(temp) + ')')
        value = str(math.acos(temp))
        final.set(value)
    except :
        value.set(" error ")
        value = "0"

def arc_tan () :
    """ arctan method """
    global value
    try :
        temp = eval(value)
        before.set('atan(' + str(temp) + ')')
        value = str(math.atan(temp))
        vfinal.set(value)
    except :
        final.set(" error ")
        value = "0"

# Hyperbolic functions (arc)

def arc_sinh () :
    """ arcsinh method """
    global value
    try :
        temp = eval(value)
        before.set('asinh(' + str(temp) + ')')
        value = str(math.asinh(temp))
        final.set(value)
    except :
        final.set(" error ")
        value = "0"

def arc_cosh () :
    """ arccosh method """
    global value
    try :
        temp = eval(value)
        before.set('acosh(' + str(temp) + ')')
        value = str(math.acosh(temp))
        final.set(value)
    except :
        final.set(" error ")
        value = "0"

def arc_tanh () :
    """ arctanh method """
    global value
    try :
        temp = eval(value)
        before.set('atanh(' + str(temp) + ')')
        value = math.atanh(temp)
        final.set(str(value))
    except :
        final.set(" error ")
        value = "0"

root = Tk()
root.title("Caculator")
root.resizable(0, 0)
root.configure(background='BlanchedAlmond')
#root.geometry('487x696')

#radioValue = IntVar()

final = StringVar()
final.set('0')

before = StringVar()
before.set('')

label_00 = Label(root, textvariable = before) 
label_00.config(width = 81, height = 1, bg = "black", fg = "white", font = "新細明體 21", anchor = SE) 

label_10 = Label(root, textvariable = final) 
label_10.config(width = 38, height = 1, bg = "black", fg = "white", font = "新細明體 45", anchor = SE) 

label_20 = Button(root, text = "二進位", bg = "BlanchedAlmond", width = 10, height = 1, font = "新細明體 16", relief = FLAT, command = Binary)
label_21 = Button(root, text = "八進位", bg = "BlanchedAlmond", width = 10, height = 1, font = "新細明體 16", relief = FLAT, command = Octal)
label_22 = Button(root, text = "十進位", bg = "yellow", width = 10, height = 1, font = "新細明體 16", relief = FLAT, command = Decimal)
label_23 = Button(root, text = "十六進位", bg = "BlanchedAlmond", width = 10, height = 1, font = "新細明體 16", relief = FLAT, command = Hexadecimal)


label_30 = Button(root, text = "(", width = 10, height = 4, bg = "Chocolate", fg = "black", font = "新細明體 16", command = lambda:get_value_sign('('))
label_40 = Button(root, text = "1st", width = 10, height = 4, bg = "plum", fg = "black", font = "新細明體 16", command = transfer)
label_50 = Button(root, text = "1/x", width = 10, height = 4, bg = "Tomato", fg = "black", font = "新細明體 16", command = over_x)
label_60 = Button(root, text = "x!", width = 10, height = 4, bg = "Tomato", fg = "black", font = "新細明體 16", command = factorial)
label_70 = Button(root, text = "rad", width = 10, height = 4, bg = "Tomato", fg = "black", font = "新細明體 16", command = rad)

label_31 = Button(root, text = ")", width = 10, height = 4, bg = "Chocolate", fg = "black", font = "新細明體 16", command = lambda:get_value_sign(')'))
label_41 = Button(root, text = "x\u00B2", width = 10, height = 4, bg = "LightSalmon", fg = "black", font = "新細明體 16", command = square)
label_51 = Button(root, text = "\u221A", width = 10, height = 4, bg = "LightSalmon", fg = "black", font = "新細明體 16", command = squareroot)
label_61 = Button(root, text = "sin", width = 10, height = 4, bg = "plum", fg = "black", font = "新細明體 16", command = sin)
label_71 = Button(root, text = "sinh", width = 10, height = 4, bg = "plum", fg = "black", font = "新細明體 16", command = sinh)

label_32 = Button(root, text = "mc", width = 10, height = 4, bg = "Tomato", fg = "black", font = "新細明體 16", command = mc)
label_42 = Button(root, text = "x\u00B3", width = 10, height = 4, bg = "LightSalmon", fg = "black", font = "新細明體 16", command = cube)
label_52 = Button(root, text = "\u221B", width = 10, height = 4, bg = "LightSalmon", fg = "black", font = "新細明體 16", command = cuberoot)
label_62 = Button(root, text = "cos", width = 10, height = 4, bg = "plum", fg = "black", font = "新細明體 16", command = cos)
label_72 = Button(root, text = "cosh", width = 10, height = 4, bg = "plum", fg = "black", font = "新細明體 16", command = cosh)
    
label_33 = Button(root, text = "m+", width = 10, height = 4, bg = "Tomato", fg = "black", font = "新細明體 16", command = m_p)
label_43 = Button(root, text = "xʸ", width = 10, height = 4, bg = "LightSalmon", fg = "black", font = "新細明體 16", command = pow_x_y)
label_53 = Button(root, text = "y\u221Ax", width = 10, height = 4, bg = "LightSalmon", fg = "black", font = "新細明體 16", command = x_root_of_y)
label_63 = Button(root, text = "tan", width = 10, height = 4, bg = "plum", fg = "black", font = "新細明體 16", command = tan)
label_73 = Button(root, text = "tanh", width = 10, height = 4, bg = "plum", fg = "black", font = "新細明體 16", command = tanh)

label_34 = Button(root, text = "m-", width = 10, height = 4, bg = "Tomato", fg = "black", font = "新細明體 16", command = m_s)
label_44 = Button(root, text = "eˣ", width = 10, height = 4, bg = "plum", fg = "black", font = "新細明體 16", command = natural_pow)
label_54 = Button(root, text = "ln", width = 10, height = 4, bg = "plum", fg = "black", font = "新細明體 16", command = natural_log)
label_64 = Button(root, text = "e", width = 10, height = 4, bg = "Tomato", fg = "black", font = "新細明體 16", command = e)
label_74 = Button(root, text = "π", width = 10, height = 4, bg = "Tomato", fg = "black", font = "新細明體 16", command = pi)

label_35 = Button(root, text = "mr", width = 10, height = 4, bg = "Tomato", fg = "black", font = "新細明體 16", command = mr)
label_45 = Button(root, text = "10ˣ", width = 10, height = 4, bg = "plum", fg = "black", font = "新細明體 16", command = pow_10)
label_55 = Button(root, text = "log10", width = 10, height = 4, bg = "plum", fg = "black", font = "新細明體 16", command = log_10)
label_65 = Button(root, text = "+/-", width = 10, height = 4, bg = "Chocolate", fg = "black", font = "新細明體 16", command = convertsigned)
label_75 = Button(root, text = "Rand", width = 10, height = 4, bg = "Tomato", fg = "black", font = "新細明體 16", command = rand)

label_36 = Button(root, text = "AC", width = 10, height = 4, bg = "plum", fg = "black", font = "新細明體 16", command = clear)
label_46 = Button(root, text = "7", width = 10, height = 4, bg = "pink", fg = "black", font = "新細明體 16", command = lambda:get_value_num('7'))
label_56 = Button(root, text = "4", width = 10, height = 4, bg = "pink", fg = "black", font = "新細明體 16", command = lambda:get_value_num('4'))
label_66 = Button(root, text = "1", width = 10, height = 4, bg = "pink", fg = "black", font = "新細明體 16", command = lambda:get_value_num('1')) 
label_767 = Button(root, text = "0", width = 21, height = 4, bg = "pink", fg = "black", font = "新細明體 16", command = lambda:get_value_num('0'))

label_37 = Button(root, text = "DEL", width = 10, height = 4, bg = "plum", fg = "black", font = "新細明體 16", command = backspace)
label_47 = Button(root, text = "8", width = 10, height = 4, bg = "pink", fg = "black", font = "新細明體 16", command = lambda:get_value_num('8'))
label_57 = Button(root, text = "5", width = 10, height = 4, bg = "pink", fg = "black", font = "新細明體 16", command = lambda:get_value_num('5'))
label_67 = Button(root, text = "2", width = 10, height = 4, bg = "pink", fg = "black", font = "新細明體 16", command = lambda:get_value_num('2'))

label_38 = Button(root, text = "%", width = 10, height = 4, bg = "plum", fg = "black", font = "新細明體 16", command = percent)
label_48 = Button(root, text = "9", width = 10, height = 4, bg = "pink", fg = "black", font = "新細明體 16", command = lambda:get_value_num('9'))
label_58 = Button(root, text = "6", width = 10, height = 4, bg = "pink", fg = "black", font = "新細明體 16", command = lambda:get_value_num('6'))
label_68 = Button(root, text = "3", width = 10, height = 4, bg = "pink", fg = "black", font = "新細明體 16", command = lambda:get_value_num('3'))
label_78 = Button(root, text = ".", width = 10, height = 4, bg = "pink", fg = "black", font = "新細明體 16", command = lambda:get_value_num('.'))

label_39 = Button(root, text = "/", width = 10, height = 4, bg = "Chocolate", fg = "white", font = "新細明體 16", command = lambda:get_value_sign('/'))
label_49 = Button(root, text = "*", width = 10, height = 4, bg = "Chocolate", fg = "white", font = "新細明體 16", command = lambda:get_value_sign('*'))
label_59 = Button(root, text = "-", width = 10, height = 4, bg = "Chocolate", fg = "white", font = "新細明體 16", command = lambda:get_value_sign('-'))
label_69 = Button(root, text = "+", width = 10, height = 4, bg = "Chocolate", fg = "white", font = "新細明體 16", command = lambda:get_value_sign('+'))
label_79 = Button(root, text = "=", width = 10, height = 4, bg = "Chocolate", fg = "white", font = "新細明體 16", command = lambda:calculate())

# grid

label_00.grid(row = 0, column = 0, columnspan = 10)
label_10.grid(row = 1, column = 0, columnspan = 10)

label_20.grid(row = 2, column = 0, padx = 1, pady = 1)
label_21.grid(row = 2, column = 1, padx = 1, pady = 1)
label_22.grid(row = 2, column = 2, padx = 1, pady = 1)
label_23.grid(row = 2, column = 3, padx = 1, pady = 1)

label_30.grid(row = 3, column = 0, padx = 1, pady = 1)
label_40.grid(row = 4, column = 0, padx = 1, pady = 1)
label_50.grid(row = 5, column = 0, padx = 1, pady = 1)
label_60.grid(row = 6, column = 0, padx = 1, pady = 1)
label_70.grid(row = 7, column = 0, padx = 1, pady = 1)

label_31.grid(row = 3, column = 1, padx = 1, pady = 1)
label_41.grid(row = 4, column = 1, padx = 1, pady = 1)
label_51.grid(row = 5, column = 1, padx = 1, pady = 1)
label_61.grid(row = 6, column = 1, padx = 1, pady = 1)
label_71.grid(row = 7, column = 1, padx = 1, pady = 1)

label_32.grid(row = 3, column = 2, padx = 1, pady = 1)
label_42.grid(row = 4, column = 2, padx = 1, pady = 1)
label_52.grid(row = 5, column = 2, padx = 1, pady = 1)
label_62.grid(row = 6, column = 2, padx = 1, pady = 1)
label_72.grid(row = 7, column = 2, padx = 1, pady = 1)

label_33.grid(row = 3, column = 3, padx = 1, pady = 1)
label_43.grid(row = 4, column = 3, padx = 1, pady = 1)
label_53.grid(row = 5, column = 3, padx = 1, pady = 1)
label_63.grid(row = 6, column = 3, padx = 1, pady = 1)
label_73.grid(row = 7, column = 3, padx = 1, pady = 1)

label_34.grid(row = 3, column = 4, padx = 1, pady = 1)
label_44.grid(row = 4, column = 4, padx = 1, pady = 1)
label_54.grid(row = 5, column = 4, padx = 1, pady = 1)
label_64.grid(row = 6, column = 4, padx = 1, pady = 1)
label_74.grid(row = 7, column = 4, padx = 1, pady = 1)

label_35.grid(row = 3, column = 5, padx = 1, pady = 1)
label_45.grid(row = 4, column = 5, padx = 1, pady = 1)
label_55.grid(row = 5, column = 5, padx = 1, pady = 1)
label_65.grid(row = 6, column = 5, padx = 1, pady = 1)
label_75.grid(row = 7, column = 5, padx = 1, pady = 1)

label_36.grid(row = 3, column = 6, padx = 1, pady = 1)
label_46.grid(row = 4, column =  6, padx = 1, pady = 1)
label_56.grid(row = 5, column = 6, padx = 1, pady = 1)
label_66.grid(row = 6, column = 6, padx = 1, pady = 1)
label_767.grid(row = 7, column = 6, padx = 1, pady = 1, columnspan = 2)

label_37.grid(row = 3, column = 7, padx = 1, pady = 1)
label_47.grid(row = 4, column = 7, padx = 1, pady = 1)
label_57.grid(row = 5, column = 7, padx = 1, pady = 1)
label_67.grid(row = 6, column = 7, padx = 1, pady = 1)

label_38.grid(row = 3, column = 8, padx = 1, pady = 1)
label_48.grid(row = 4, column = 8, padx = 1, pady = 1) 
label_58.grid(row = 5, column = 8, padx = 1, pady = 1)
label_68.grid(row = 6, column = 8, padx = 1, pady = 1)
label_78.grid(row = 7, column = 8, padx = 1, pady = 1)

label_39.grid(row = 3, column = 9, padx = 1, pady = 1)
label_49.grid(row = 4, column = 9, padx = 1, pady = 1)
label_59.grid(row = 5, column = 9, padx = 1, pady = 1)
label_69.grid(row = 6, column = 9, padx = 1, pady = 1)
label_79.grid(row = 7, column = 9, padx = 1, pady = 1)


root.mainloop()
